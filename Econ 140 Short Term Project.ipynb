# %%
library(tidyverse)
library(haven)
install.packages("readxl")
install.packages("vembedr")
install.packages("Hmisc")
install.packages("ggplot2")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Installing package into ‘/opt/r’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/opt/r’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/opt/r’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/opt/r’
# (as ‘lib’ is unspecified)

# %%
library(readxl)

# %%
WDI_data <- read_excel("WDI140export.xlsx")

# %%
head(WDI_data)
# Out:
#   Country Name   Country Code AG.CON.FERT.ZS AG.LND.ARBL.HA AG.LND.CROP.ZS
# 1 Afghanistan    AFG            8.714495     7829000        0.4062984
# 2 Albania        ALB          101.428185      599600        3.2100365
# 3 Algeria        DZA           20.746122     7505017        0.4248993
# 4 American Samoa ASM                  NA        3190        3.7500000
# 5 Andorra        AND                  NA         720               NA
# 6 Angola         AGO            8.598882     4900000        0.2526670
#   AG.LND.IRIG.AG.ZS AG.LND.TOTL.K2 AG.YLD.CREL.KG BM.GSR.FCTY.CD BM.GSR.GNFS.CD
# 1  327               652230        1979.9           45904588      7370819805
# 2 1485                27400        5209.2          671672557      6925814672
# 3   89              2381741        1520.4         5295631308     54258989925
# 4   NA                  200            NA                 NA              NA
# 5   NA                  470            NA          264874383      2032100364
# 6 1010              1246700         906.6         8208899954     22299328651
#   ⋯ SP.DYN.CDRT.IN SP.DYN.LE00.IN SP.DYN.TFRT.IN SP.POP.0014.TO SP.POP.1564.TO
# 1 ⋯ 6.285          64.833         4.321          16157198       20889465
# 2 ⋯ 8.082          78.573         1.597            496617        1952204
# 3 ⋯ 4.716          76.880         2.988          13152871       27079012
# 4 ⋯    NA              NA            NA                NA             NA
# 5 ⋯ 3.900              NA            NA                NA             NA
# 6 ⋯ 7.981          61.147         5.442          14837599       16287753
#   SP.POP.65UP.TO SP.POP.GROW SP.POP.TOTL SP.URB.TOTL VC.IHR.PSRC.P5
# 1  995094         2.3130733  38041757     9797274    6.1965460
# 2  405370        -0.4260074   2854191     1747593    3.3165158
# 3 2821171         1.9339833  43053054    31510100    1.2028565
# 4      NA        -0.2690188     55312       48203    5.5983935
# 5      NA         0.1790418     77146       67876    0.5403646
# 6  699947         3.2429140  31825299    21061028    4.6014303

# %%
ggplot(data = WDI_data, aes(x = SE.ADT.LITR.ZS, y = SP.DYN.LE00.IN)) + geom_point()
# Out:
# Warning message:
# “Removed 67 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggplot(data = WDI_data, aes(x = SE.SEC.CUAT.UP.ZS, y = SP.DYN.LE00.IN)) + geom_point()
# Out:
# Warning message:
# “Removed 80 rows containing missing values (`geom_point()`).”
# plot without title

# %%
ggplot(data = WDI_data, aes(x = SE.TER.CUAT.BA.ZS, y = SP.DYN.LE00.IN)) + geom_point()
# Out:
# Warning message:
# “Removed 102 rows containing missing values (`geom_point()`).”
# plot without title

# %%
edu_reg <- lm(SP.DYN.LE00.IN ~ SE.ADT.LITR.ZS + SE.SEC.CUAT.UP.ZS + SE.TER.CUAT.BA.ZS, data = WDI_data)
summary (edu_reg)
# Out:
# Call:
# lm(formula = SP.DYN.LE00.IN ~ SE.ADT.LITR.ZS + SE.SEC.CUAT.UP.ZS +
#     SE.TER.CUAT.BA.ZS, data = WDI_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -11.424  -2.787   0.126   2.865   7.423
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)       51.52086    2.56086  20.119  < 2e-16 ***
# SE.ADT.LITR.ZS     0.24797    0.03662   6.771 1.78e-09 ***
# SE.SEC.CUAT.UP.ZS -0.02662    0.02946  -0.904    0.369
# SE.TER.CUAT.BA.ZS  0.10190    0.06570   1.551    0.125
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.126 on 82 degrees of freedom
#   (131 observations deleted due to missingness)
# Multiple R-squared:  0.5568,	Adjusted R-squared:  0.5406
# F-statistic: 34.35 on 3 and 82 DF,  p-value: 1.773e-14

# %%
edu_reg <- lm(SP.DYN.LE00.IN ~ SE.ADT.LITR.ZS, data = WDI_data)
summary (edu_reg)
# Out:
# Call:
# lm(formula = SP.DYN.LE00.IN ~ SE.ADT.LITR.ZS, data = WDI_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -15.6777  -2.8693   0.5897   3.2242   9.3587
#
# Coefficients:
#                Estimate Std. Error t value Pr(>|t|)
# (Intercept)    48.46256    1.71016   28.34   <2e-16 ***
# SE.ADT.LITR.ZS  0.27498    0.02005   13.71   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.763 on 148 degrees of freedom
#   (67 observations deleted due to missingness)
# Multiple R-squared:  0.5596,	Adjusted R-squared:  0.5566
# F-statistic:   188 on 1 and 148 DF,  p-value: < 2.2e-16

# %%
edu_reg <- lm(SP.DYN.LE00.IN ~ SE.SEC.CUAT.UP.ZS, data = WDI_data)
summary (edu_reg)
# Out:
# Call:
# lm(formula = SP.DYN.LE00.IN ~ SE.SEC.CUAT.UP.ZS, data = WDI_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -12.527  -3.615   1.271   3.793  10.628
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)       66.22862    0.92154   71.87   <2e-16 ***
# SE.SEC.CUAT.UP.ZS  0.16652    0.01623   10.26   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.033 on 135 degrees of freedom
#   (80 observations deleted due to missingness)
# Multiple R-squared:  0.4381,	Adjusted R-squared:  0.434
# F-statistic: 105.3 on 1 and 135 DF,  p-value: < 2.2e-16

# %%
edu_reg <- lm(SP.DYN.LE00.IN ~ SE.TER.CUAT.BA.ZS, data = WDI_data)
summary (edu_reg)
# Out:
# Call:
# lm(formula = SP.DYN.LE00.IN ~ SE.TER.CUAT.BA.ZS, data = WDI_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -17.470  -3.050   1.122   3.344   8.494
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)       68.98015    0.85071  81.086  < 2e-16 ***
# SE.TER.CUAT.BA.ZS  0.36405    0.04306   8.455 1.11e-13 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4.962 on 113 degrees of freedom
#   (102 observations deleted due to missingness)
# Multiple R-squared:  0.3875,	Adjusted R-squared:  0.3821
# F-statistic: 71.48 on 1 and 113 DF,  p-value: 1.114e-13
